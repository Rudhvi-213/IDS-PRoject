# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

data_set = pd.read_csv(r"C:\Users\Rudhvi\OneDrive\Desktop\ids\Prodution-Under-Different-Crops_during-2019-20.csv")
data_set
# Out:
#                State      District  Wheat ( in Metric Tonnes)  \
# 0   Himachal Pradesh      Bilaspur                      48096
# 1   Himachal Pradesh        Chamba                      41545
# 2   Himachal Pradesh      Hamirpur                      58886
# 3   Himachal Pradesh        Kangra                     190519
# 4   Himachal Pradesh       Kinnaur                        196
# 5   Himachal Pradesh         Kullu                      21992
# 6   Himachal Pradesh  Lahaul-spiti                        125
# 7   Himachal Pradesh         Mandi                     117665
# 8   Himachal Pradesh        Shimla                      13819
# 9   Himachal Pradesh       Sirmaur                      40567
# 10  Himachal Pradesh         Solan                      43236
# 11  Himachal Pradesh           Una                      43043
# 12  Himachal Pradesh         Total                     619689
#
#     Maize ( in Metric Tonnes)  Rice ( in Metric Tonnes)  \
# ...

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 13 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   State                                  13 non-null     object
#  1   District                               13 non-null     object
#  2   Wheat ( in Metric Tonnes)              13 non-null     int64
#  3   Maize ( in Metric Tonnes)              13 non-null     int64
#  4   Rice ( in Metric Tonnes)               13 non-null     int64
#  5   Barley ( in Metric Tonnes)             13 non-null     int64
#  6   Ragi ( in Metric Tonnes)               13 non-null     int64
#  7   Pulses ( in Metric Tonnes)             13 non-null     int64
#  8   Common millets ( in Metric Tonnes)     13 non-null     int64
#  9   Total Food grains ( in Metric Tonnes)  13 non-null     int64
#  10  Chillies ( in Metric Tonnes)           13 non-null     int64
# ...

# %%
data_set.drop('State', axis = 1, inplace = True)
data_set
# Out:
#         District  Wheat ( in Metric Tonnes)  Maize ( in Metric Tonnes)  \
# 0       Bilaspur                      48096                      54634
# 1         Chamba                      41545                      68768
# 2       Hamirpur                      58886                      88041
# 3         Kangra                     190519                     136597
# 4        Kinnaur                        196                        217
# 5          Kullu                      21992                      42826
# 6   Lahaul-spiti                        125                         69
# 7          Mandi                     117665                     128742
# 8         Shimla                      13819                      23058
# 9        Sirmaur                      40567                      55159
# 10         Solan                      43236                      59453
# 11           Una                      43043                      87039
# ...

# %%
rename = {
    "Wheat ( in Metric Tonnes)":'Wheat',
    "Maize ( in Metric Tonnes)": "Maize",
    "Rice ( in Metric Tonnes)": "Rice",
    "Barley ( in Metric Tonnes)":"Barley",
    "Ragi ( in Metric Tonnes)": "Ragi",
    "Pulses ( in Metric Tonnes)": "Pulses",
    "Common millets ( in Metric Tonnes)": "Common millets",
    "Chillies ( in Metric Tonnes)": "Chillies",
    "Ginger ( in Metric Tonnes)": "Ginger",
    "Oil  seeds ( in Metric Tonnes)": "Oil  seeds",
    "Total Food grains ( in Metric Tonnes)":"Total Food grains"
}
data = data_set.rename(columns=(rename))
data
# Out:
#         District   Wheat   Maize    Rice  Barley  Ragi  Pulses  \
# 0       Bilaspur   48096   54634    2851     231     6     141
# 1         Chamba   41545   68768    4485    7726    22    8227
# 2       Hamirpur   58886   88041    2907     167     0      34
# 3         Kangra  190519  136597   52824    4205     4    7674
# 4        Kinnaur     196     217      15    1325    10     716
# 5          Kullu   21992   42826    1763    3694   216    7760
# 6   Lahaul-spiti     125      69       0     988     0     923
# 7          Mandi  117665  128742   29216    6054   744    9460
# 8         Shimla   13819   23058     780    4558   647    9128
# 9        Sirmaur   40567   55159    7932    3890   411    9030
# 10         Solan   43236   59453    9985    2575     0    2007
# 11           Una   43043   87039    4121       0     0     128
# 12         Total  619689  744603  116879   35413  2060   55228
#
#     Common millets  Total Food grains  Chillies  Ginger  Oil  seeds
# ...

# %%
data.set_index("District", inplace=True)
data
# Out:
#                Wheat   Maize    Rice  Barley  Ragi  Pulses  Common millets  \
# District
# Bilaspur       48096   54634    2851     231     6     141               0
# Chamba         41545   68768    4485    7726    22    8227            1029
# Hamirpur       58886   88041    2907     167     0      34               0
# Kangra        190519  136597   52824    4205     4    7674              93
# Kinnaur          196     217      15    1325    10     716             874
# Kullu          21992   42826    1763    3694   216    7760             133
# Lahaul-spiti     125      69       0     988     0     923              29
# Mandi         117665  128742   29216    6054   744    9460             815
# Shimla         13819   23058     780    4558   647    9128            1611
# Sirmaur        40567   55159    7932    3890   411    9030              73
# Solan          43236   59453    9985    2575     0    2007               0
# ...

# %%
mean_district_production = (data[:12]["Total Food grains"]/10)
round(mean_district_production, 2)
# Out:
# District
# Bilaspur        10595.9
# Chamba          13180.2
# Hamirpur        15003.5
# Kangra          39191.6
# Kinnaur           335.3
# Kullu            7838.4
# Lahaul-spiti      213.4
# Mandi           29269.6
# Shimla           5360.1
# Sirmaur         11706.2
# Solan           11725.6
# Una             13433.1
# Name: Total Food grains, dtype: float64

# %%
mean_hp = data[:12]["Total Food grains"].mean()
round(mean_hp, 2)
# Out:
# 131544.08

# %%
data[:12]["Total Food grains"].plot.bar()
# Out:
# <AxesSubplot: xlabel='District'>

# %%
data.drop('Total Food grains', axis = 1, inplace = True)
data
# Out:
#                Wheat   Maize    Rice  Barley  Ragi  Pulses  Common millets  \
# District
# Bilaspur       48096   54634    2851     231     6     141               0
# Chamba         41545   68768    4485    7726    22    8227            1029
# Hamirpur       58886   88041    2907     167     0      34               0
# Kangra        190519  136597   52824    4205     4    7674              93
# Kinnaur          196     217      15    1325    10     716             874
# Kullu          21992   42826    1763    3694   216    7760             133
# Lahaul-spiti     125      69       0     988     0     923              29
# Mandi         117665  128742   29216    6054   744    9460             815
# Shimla         13819   23058     780    4558   647    9128            1611
# Sirmaur        40567   55159    7932    3890   411    9030              73
# Solan          43236   59453    9985    2575     0    2007               0
# ...

# %%
copy_data = data.copy()
d_tdf = copy_data.T
d_tdf
# Out:
# District        Bilaspur  Chamba  Hamirpur  Kangra  Kinnaur  Kullu  \
# Wheat              48096   41545     58886  190519      196  21992
# Maize              54634   68768     88041  136597      217  42826
# Rice                2851    4485      2907   52824       15   1763
# Barley               231    7726       167    4205     1325   3694
# Ragi                   6      22         0       4       10    216
# Pulses               141    8227        34    7674      716   7760
# Common millets         0    1029         0      93      874    133
# Chillies               2      21         5       3        0     40
# Ginger               361      15        30      86        0    336
# Oil  seeds           159    1176        33    1992        0    167
#
# District        Lahaul-spiti   Mandi  Shimla  Sirmaur  Solan    Una   Total
# Wheat                    125  117665   13819    40567  43236  43043  619689
# Maize                     69  128742   23058    55159  59453  87039  744603
# ...

# %%
mean_crop_production = (d_tdf["Total"]/12)
round(mean_crop_production, 2)
# Out:
# Wheat             51640.75
# Maize             62050.25
# Rice               9739.92
# Barley             2951.08
# Ragi                171.67
# Pulses             4602.33
# Common millets      388.08
# Chillies             23.00
# Ginger              889.58
# Oil  seeds          537.00
# Name: Total, dtype: float64

# %%
d_tdf["Total"].plot.bar()
# Out:
# <AxesSubplot: >

# %%
data = data[:12]
data
# Out:
#                Wheat   Maize   Rice  Barley  Ragi  Pulses  Common millets  \
# District
# Bilaspur       48096   54634   2851     231     6     141               0
# Chamba         41545   68768   4485    7726    22    8227            1029
# Hamirpur       58886   88041   2907     167     0      34               0
# Kangra        190519  136597  52824    4205     4    7674              93
# Kinnaur          196     217     15    1325    10     716             874
# Kullu          21992   42826   1763    3694   216    7760             133
# Lahaul-spiti     125      69      0     988     0     923              29
# Mandi         117665  128742  29216    6054   744    9460             815
# Shimla         13819   23058    780    4558   647    9128            1611
# Sirmaur        40567   55159   7932    3890   411    9030              73
# Solan          43236   59453   9985    2575     0    2007               0
# ...

# %%
print(data.isnull().sum())
# Out:
# Wheat             0
# Maize             0
# Rice              0
# Barley            0
# Ragi              0
# Pulses            0
# Common millets    0
# Chillies          0
# Ginger            0
# Oil  seeds        0
# dtype: int64

# %%
sns.scatterplot(data)
# Out:
# <AxesSubplot: xlabel='District'>

# %%
arr = ['Wheat', 'Maize', "Rice", "Barley", "Ragi", "Pulses", "Common millets", "Chillies", "Ginger", "Oil  seeds"]
sns.pairplot(data = data, vars=arr)
plt.show()

# %%
sns.heatmap(data[arr].corr(), annot=True, cmap = 'Reds')
plt.show()

# %%
result = pd.pivot_table(data=data, index='District')

sns.heatmap(result, annot=True, cmap = 'RdYlGn', center=0.117,)
plt.show()

# %%
sns.scatterplot(x=data["Rice"],y=data["Barley"],hue=data.index)
# Out:
# <AxesSubplot: xlabel='Rice', ylabel='Barley'>

# %%
plt.hist(data["Barley"])
# Out:
# (array([3., 2., 0., 1., 1., 3., 0., 1., 0., 1.]),
#  array([   0. ,  772.6, 1545.2, 2317.8, 3090.4, 3863. , 4635.6, 5408.2,
#         6180.8, 6953.4, 7726. ]),
#  <BarContainer object of 10 artists>)

# %%
arr = ['Wheat', 'Maize', "Rice", "Barley", "Ragi", "Pulses", "Common millets", "Chillies", "Ginger", "Oil  seeds"]
boxplot = data[arr].plot(kind='box', title='boxplot')

# %%
sns.kdeplot(data["Ginger"],shade=True)
# Out:
# C:\Users\Rudhvi\AppData\Local\Temp\ipykernel_10756\164181944.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data["Ginger"],shade=True)
# <AxesSubplot: xlabel='Ginger', ylabel='Density'>

# %%
plt.violinplot([data["Barley"], data["Chillies"]],showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x126e60f2200>,
# ...
#  'cmaxes': <matplotlib.collections.LineCollection at 0x126e60f2110>,
#  'cmins': <matplotlib.collections.LineCollection at 0x126e60f2b90>,
#  'cbars': <matplotlib.collections.LineCollection at 0x126e60f2f20>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x126e60f32b0>}

# %%
data["Wheat"].plot.bar()
# Out:
# <AxesSubplot: xlabel='District'>

# %%
data["Maize"].plot.bar()
# Out:
# <AxesSubplot: xlabel='District'>

# %%
data["Rice"].plot.bar()
# Out:
# <AxesSubplot: xlabel='District'>

# %%
data["Barley"].plot.bar()
# Out:
# <AxesSubplot: xlabel='District'>

# %%
data["Ragi"].plot.bar()
# Out:
# <AxesSubplot: xlabel='District'>

# %%
data["Pulses"].plot.bar()
# Out:
# <AxesSubplot: xlabel='District'>

# %%
data["Common millets"].plot.bar()
# Out:
# <AxesSubplot: xlabel='District'>

# %%
data["Chillies"].plot.bar()
# Out:
# <AxesSubplot: xlabel='District'>

# %%
data["Ginger"].plot.bar()
# Out:
# <AxesSubplot: xlabel='District'>

# %%
data["Oil  seeds"].plot.bar()
# Out:
# <AxesSubplot: xlabel='District'>

# %%
data["Maize"].plot.pie(autopct='%.3f')
# Out:
# <AxesSubplot: ylabel='Maize'>

# %%
tdf = data.T
tdf
# Out:
# District        Bilaspur  Chamba  Hamirpur  Kangra  Kinnaur  Kullu  \
# Wheat              48096   41545     58886  190519      196  21992
# Maize              54634   68768     88041  136597      217  42826
# Rice                2851    4485      2907   52824       15   1763
# Barley               231    7726       167    4205     1325   3694
# Ragi                   6      22         0       4       10    216
# Pulses               141    8227        34    7674      716   7760
# Common millets         0    1029         0      93      874    133
# Chillies               2      21         5       3        0     40
# Ginger               361      15        30      86        0    336
# Oil  seeds           159    1176        33    1992        0    167
#
# District        Lahaul-spiti   Mandi  Shimla  Sirmaur  Solan    Una
# Wheat                    125  117665   13819    40567  43236  43043
# Maize                     69  128742   23058    55159  59453  87039
# ...

# %%
sns.scatterplot(tdf)
# Out:
# <AxesSubplot: >

# %%
sns.scatterplot(x=tdf["Lahaul-spiti"],y=tdf["Kinnaur"],hue=tdf.index)
# Out:
# <AxesSubplot: xlabel='Lahaul-spiti', ylabel='Kinnaur'>

# %%
dist_arr = ['Bilaspur', 'Chamba', "Hamirpur", "Kangra", "Kinnaur", "Kullu", "Lahaul-spiti", "Mandi", "Shimla", "Sirmaur", "Solan", "Una"]
sns.heatmap(tdf[dist_arr].corr(), annot=True, cmap = 'Reds')
plt.show()

# %%
dist_arr = ['Bilaspur', 'Chamba', "Hamirpur", "Kangra", "Kinnaur", "Kullu", "Lahaul-spiti", "Mandi", "Shimla", "Sirmaur", "Solan", "Una"]
tdf[dist_arr].plot(kind='box', title='boxplot')
# Out:
# <AxesSubplot: title={'center': 'boxplot'}>

# %%
sns.kdeplot(tdf["Hamirpur"],shade=True)
# Out:
# C:\Users\Rudhvi\AppData\Local\Temp\ipykernel_10756\3672406200.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tdf["Hamirpur"],shade=True)
# <AxesSubplot: xlabel='Hamirpur', ylabel='Density'>

# %%
sns.pairplot(data = tdf, vars=dist_arr)
plt.show()

# %%
plt.hist(tdf["Chamba"])
# Out:
# (array([6., 2., 0., 0., 0., 0., 1., 0., 0., 1.]),
#  array([1.50000e+01, 6.89030e+03, 1.37656e+04, 2.06409e+04, 2.75162e+04,
#         3.43915e+04, 4.12668e+04, 4.81421e+04, 5.50174e+04, 6.18927e+04,
#         6.87680e+04]),
#  <BarContainer object of 10 artists>)

# %%
tdf["Bilaspur"].plot.bar()
# Out:
# <AxesSubplot: >

# %%
tdf["Chamba"].plot.bar()
# Out:
# <AxesSubplot: >

# %%
tdf["Hamirpur"].plot.bar()
# Out:
# <AxesSubplot: >

# %%
tdf["Kangra"].plot.bar()
# Out:
# <AxesSubplot: >

# %%
tdf["Kinnaur"].plot.bar()
# Out:
# <AxesSubplot: >

# %%
tdf["Kullu"].plot.bar()
# Out:
# <AxesSubplot: >

# %%
tdf["Lahaul-spiti"].plot.bar()
# Out:
# <AxesSubplot: >

# %%
tdf["Mandi"].plot.bar()
# Out:
# <AxesSubplot: >

# %%
tdf["Shimla"].plot.bar()
# Out:
# <AxesSubplot: >

# %%
tdf["Sirmaur"].plot.bar()
# Out:
# <AxesSubplot: >

# %%
tdf["Solan"].plot.bar()
# Out:
# <AxesSubplot: >

# %%
tdf["Una"].plot.bar()
# Out:
# <AxesSubplot: >

# %%
tdf["Mandi"].plot.pie(autopct='%.3f')
# Out:
# <AxesSubplot: ylabel='Mandi'>
